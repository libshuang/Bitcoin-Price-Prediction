# %%
import pandas as pd

from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, GRU, LSTM
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator

import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Import Data

# %%
df = pd.read_csv('./Reddit_data/Combined_Yearly_Data/stage5_final2019.csv')
df
# Out:
#            Date   created_utc  score  vader_neu_score  vader_pos_score  \
# 0    2019-01-01  2.706142e+11    175          136.468           26.410
# 1    2019-01-02  4.422842e+11    286          225.624           37.963
# 2    2019-01-03  4.577735e+11    296          225.704           46.506
# 3    2019-01-04  3.603619e+11    233          191.788           30.535
# 4    2019-01-07  3.820787e+11    251          194.829           35.885
# ..          ...           ...    ...              ...              ...
# 259  2019-12-31  2.019603e+11    130           91.469           25.459
# 260  2020-01-01  1.956599e+11    124           94.982           20.297
# 261  2020-01-02  2.793038e+11   1411          136.657           25.557
# 262  2020-01-03  2.935215e+11   4390          144.610           28.309
# 263  2020-01-06  8.680670e+10     55           41.351           10.157
#
#      vader_neg_score  vader_compound  blob_polarity  blob_subjectivity  \
# 0             11.123         42.7160      24.720324          55.035224
# 1             22.408         42.5077      20.725735          82.114492
# 2             20.787         60.4147      34.251326          98.111408
# 3             10.672         46.2377      27.768522          66.136730
# 4             16.279         40.4055      12.239006          70.893338
# ..               ...             ...            ...                ...
# 259           10.074         27.8508      13.747032          41.516811
# 260            8.720         28.5484      13.026155          38.683947
# 261           13.783         30.7325      14.069506          51.179923
# 262           13.078         24.5729      16.375188          50.544828
# 263            3.489         16.0805       6.974847          18.437123
#
#      sum_posts_x  sum_posts_y  b_cash_price    btc_price  ltc_price  \
# 0            175          175    164.854599  3715.564441  31.979933
# 1            286          286    171.827377  3882.304754  33.433681
# 2            296          296    162.049927  3795.592741  32.026699
# 3            233          233    161.395630  3812.381108  32.404167
# 4            247          247    161.243973  3989.631741  37.806274
# ..           ...          ...           ...          ...        ...
# 259          128          128    204.623169  7179.957819  41.340073
# 260          124          124    204.397537  7174.744012  42.017719
# 261          177          177    195.698563  6955.487580  39.823013
# 262          186          186    222.412979  7291.219505  42.415577
# 263           55           55    244.557205  7713.860754  45.816353
#
#       eth_price
# 0    137.727646
# 1    153.965636
# 2    148.796873
# 3    152.873631
# 4    149.600165
# ..          ...
# 259  128.722604
# 260  129.887363
# 261  127.055601
# 262  132.970833
# 263  143.131601
#
# [264 rows x 15 columns]

# %%
features = list(df.columns)[3:9]
features_btc = features + ['btc_price']
feat_btc = df[features_btc]

# %%
target = df[['btc_price']]

# %% [markdown]
# ### LSTM Modeling

# %%
look_back = 4

# %%
X = feat_btc
y = target.values

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2,shuffle = False, random_state = 13)

ss = StandardScaler()
X_train_sc = ss.fit_transform(X_train)
X_test_sc = ss.transform(X_test)

train_seq = TimeseriesGenerator(X_train_sc, y_train, length = look_back, batch_size = 128)
test_seq = TimeseriesGenerator(X_test_sc, y_test, length = look_back, batch_size = 128)

# %%
model = Sequential()

model.add(LSTM(64, input_shape=(3,7), return_sequences = True))
model.add(Dense(1))

model.compile(loss='mean_squared_error', optimizer='sgd', metrics = ['mae'])

# %%
hist = model.fit(train_seq, epochs=80, validation_data = test_seq)
# Out:
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 2 steps, validate for 1 steps
# Epoch 1/80
# 2/2 [==============================] - 5s 3s/step - loss: 64889980.4444 - mae: 7136.3877 - val_loss: 49896460.0000 - val_mae: 7027.3018
# Epoch 2/80
# 2/2 [==============================] - 0s 52ms/step - loss: 47972646.5572 - mae: 5808.8887 - val_loss: 13878208.0000 - val_mae: 3589.4492
# Epoch 3/80
# 2/2 [==============================] - 0s 41ms/step - loss: 20601817.2882 - mae: 3536.5029 - val_loss: 2554416.2500 - val_mae: 1183.8503
# Epoch 4/80
# 2/2 [==============================] - 0s 45ms/step - loss: 14064528.4348 - mae: 3071.9231 - val_loss: 7871393.5000 - val_mae: 2494.3181
# Epoch 5/80
# 2/2 [==============================] - 0s 48ms/step - loss: 7075949.4803 - mae: 2033.4055 - val_loss: 2355288.2500 - val_mae: 1223.2434
# Epoch 6/80
# 2/2 [==============================] - 0s 42ms/step - loss: 4182507.3913 - mae: 1461.7141 - val_loss: 2798875.0000 - val_mae: 1397.1136
# Epoch 7/80
# 2/2 [==============================] - 0s 48ms/step - loss: 3434761.3170 - mae: 1337.9236 - val_loss: 1546468.1250 - val_mae: 1018.9785
# Epoch 8/80
# 2/2 [==============================] - 0s 50ms/step - loss: 2428373.6176 - mae: 1165.7861 - val_loss: 1814364.2500 - val_mae: 1126.1410
# Epoch 9/80
# 2/2 [==============================] - 0s 47ms/step - loss: 1952378.2983 - mae: 1037.4272 - val_loss: 1984474.2500 - val_mae: 1125.3401
# Epoch 10/80
# 2/2 [==============================] - 0s 47ms/step - loss: 1462917.4249 - mae: 837.0818 - val_loss: 1247422.5000 - val_mae: 882.1049
# Epoch 11/80
# 2/2 [==============================] - 0s 47ms/step - loss: 1324873.3110 - mae: 830.8069 - val_loss: 1077836.1250 - val_mae: 818.8454
# Epoch 12/80
# 2/2 [==============================] - 0s 48ms/step - loss: 1475072.2669 - mae: 909.6426 - val_loss: 1249821.2500 - val_mae: 896.4169
# Epoch 13/80
# 2/2 [==============================] - 0s 51ms/step - loss: 1263793.7506 - mae: 778.8964 - val_loss: 961872.2500 - val_mae: 762.1830
# Epoch 14/80
# 2/2 [==============================] - 0s 48ms/step - loss: 1381306.2387 - mae: 865.8691 - val_loss: 2120678.5000 - val_mae: 1143.8903
# Epoch 15/80
# 2/2 [==============================] - 0s 49ms/step - loss: 1265543.8756 - mae: 812.6974 - val_loss: 1437370.6250 - val_mae: 982.8333
# Epoch 16/80
# 2/2 [==============================] - 0s 47ms/step - loss: 1205941.9167 - mae: 839.8531 - val_loss: 1438043.6250 - val_mae: 976.6389
# Epoch 17/80
# 2/2 [==============================] - 0s 46ms/step - loss: 1111437.7077 - mae: 764.3826 - val_loss: 1453526.7500 - val_mae: 975.6521
# Epoch 18/80
# 2/2 [==============================] - 0s 50ms/step - loss: 967238.2562 - mae: 715.8026 - val_loss: 1332058.0000 - val_mae: 912.8536
# Epoch 19/80
# 2/2 [==============================] - 0s 47ms/step - loss: 852458.1030 - mae: 669.2269 - val_loss: 1622664.1250 - val_mae: 982.4227
# Epoch 20/80
# 2/2 [==============================] - 0s 47ms/step - loss: 871063.0181 - mae: 686.9551 - val_loss: 1466469.7500 - val_mae: 935.0720
# Epoch 21/80
# 2/2 [==============================] - 0s 46ms/step - loss: 854575.0837 - mae: 692.1298 - val_loss: 1442802.5000 - val_mae: 920.0101
# Epoch 22/80
# 2/2 [==============================] - 0s 40ms/step - loss: 808484.3853 - mae: 654.5209 - val_loss: 1444133.7500 - val_mae: 956.1560
# Epoch 23/80
# 2/2 [==============================] - 0s 46ms/step - loss: 807613.2415 - mae: 655.7974 - val_loss: 1366590.1250 - val_mae: 950.6833
# Epoch 24/80
# 2/2 [==============================] - 0s 53ms/step - loss: 717409.3808 - mae: 625.0766 - val_loss: 1377614.5000 - val_mae: 942.5425
# Epoch 25/80
# 2/2 [==============================] - 0s 54ms/step - loss: 766741.7440 - mae: 632.0763 - val_loss: 1122133.0000 - val_mae: 835.7798
# Epoch 26/80
# 2/2 [==============================] - 0s 47ms/step - loss: 776763.1132 - mae: 667.5076 - val_loss: 1282664.8750 - val_mae: 917.8005
# Epoch 27/80
# 2/2 [==============================] - 0s 45ms/step - loss: 785657.8116 - mae: 644.6458 - val_loss: 1044090.3125 - val_mae: 830.1107
# Epoch 28/80
# 2/2 [==============================] - 0s 45ms/step - loss: 815882.8582 - mae: 677.1985 - val_loss: 1303724.1250 - val_mae: 890.4657
# Epoch 29/80
# 2/2 [==============================] - 0s 47ms/step - loss: 780072.5368 - mae: 644.4490 - val_loss: 1514234.5000 - val_mae: 1027.6274
# Epoch 30/80
# 2/2 [==============================] - 0s 43ms/step - loss: 790494.5306 - mae: 672.6155 - val_loss: 1211558.8750 - val_mae: 908.9728
# Epoch 31/80
# 2/2 [==============================] - 0s 46ms/step - loss: 736409.5906 - mae: 616.0256 - val_loss: 1110314.5000 - val_mae: 863.5776
# Epoch 32/80
# 2/2 [==============================] - 0s 47ms/step - loss: 804197.2154 - mae: 673.2347 - val_loss: 903316.6250 - val_mae: 784.2763
# Epoch 33/80
# 2/2 [==============================] - 0s 48ms/step - loss: 644269.8390 - mae: 590.3113 - val_loss: 872514.3125 - val_mae: 783.9930
# Epoch 34/80
# 2/2 [==============================] - 0s 52ms/step - loss: 608380.8591 - mae: 559.0596 - val_loss: 1319794.6250 - val_mae: 966.6624
# Epoch 35/80
# 2/2 [==============================] - 0s 56ms/step - loss: 713656.5976 - mae: 615.0267 - val_loss: 927145.0000 - val_mae: 797.1343
# Epoch 36/80
# 2/2 [==============================] - 0s 42ms/step - loss: 706172.5963 - mae: 602.7053 - val_loss: 945483.8125 - val_mae: 810.2677
# Epoch 37/80
# 2/2 [==============================] - 0s 43ms/step - loss: 622823.6177 - mae: 551.7143 - val_loss: 966561.8125 - val_mae: 830.0343
# Epoch 38/80
# 2/2 [==============================] - 0s 45ms/step - loss: 677089.8962 - mae: 584.4077 - val_loss: 907807.5625 - val_mae: 796.0950
# Epoch 39/80
# 2/2 [==============================] - 0s 45ms/step - loss: 726002.9372 - mae: 621.6473 - val_loss: 804855.5625 - val_mae: 751.1193
# Epoch 40/80
# 2/2 [==============================] - 0s 43ms/step - loss: 673902.7927 - mae: 591.7939 - val_loss: 695060.1875 - val_mae: 663.9346
# Epoch 41/80
# 2/2 [==============================] - 0s 45ms/step - loss: 715875.8585 - mae: 613.9379 - val_loss: 798985.6875 - val_mae: 723.4180
# Epoch 42/80
# 2/2 [==============================] - 0s 45ms/step - loss: 609028.2230 - mae: 563.4091 - val_loss: 775514.7500 - val_mae: 711.5373
# Epoch 43/80
# 2/2 [==============================] - 0s 47ms/step - loss: 622943.0774 - mae: 553.6758 - val_loss: 778789.0625 - val_mae: 712.4281
# Epoch 44/80
# 2/2 [==============================] - 0s 46ms/step - loss: 610680.4695 - mae: 543.9015 - val_loss: 732665.3125 - val_mae: 694.4109
# Epoch 45/80
# 2/2 [==============================] - 0s 48ms/step - loss: 550836.5217 - mae: 520.5421 - val_loss: 899125.1250 - val_mae: 791.4492
# Epoch 46/80
# 2/2 [==============================] - 0s 51ms/step - loss: 582198.9379 - mae: 540.9296 - val_loss: 975488.3125 - val_mae: 848.5690
# Epoch 47/80
# 2/2 [==============================] - 0s 42ms/step - loss: 571688.9619 - mae: 536.9805 - val_loss: 890349.8125 - val_mae: 808.8901
# Epoch 48/80
# 2/2 [==============================] - 0s 39ms/step - loss: 646028.1979 - mae: 567.7928 - val_loss: 902055.6875 - val_mae: 804.7924
# Epoch 49/80
# 2/2 [==============================] - 0s 45ms/step - loss: 560574.7583 - mae: 525.3887 - val_loss: 922792.7500 - val_mae: 811.8469
# Epoch 50/80
# 2/2 [==============================] - 0s 38ms/step - loss: 579836.7627 - mae: 530.9294 - val_loss: 902816.4375 - val_mae: 813.3573
# Epoch 51/80
# 2/2 [==============================] - 0s 40ms/step - loss: 558306.7874 - mae: 516.7514 - val_loss: 964034.9375 - val_mae: 820.1119
# Epoch 52/80
# 2/2 [==============================] - 0s 42ms/step - loss: 673324.5103 - mae: 590.1824 - val_loss: 895404.2500 - val_mae: 770.1647
# Epoch 53/80
# 2/2 [==============================] - 0s 46ms/step - loss: 720174.5077 - mae: 595.4477 - val_loss: 691937.3750 - val_mae: 686.9788
# Epoch 54/80
# 2/2 [==============================] - 0s 44ms/step - loss: 680506.2261 - mae: 598.0049 - val_loss: 625968.8750 - val_mae: 640.1028
# Epoch 55/80
# 2/2 [==============================] - 0s 51ms/step - loss: 783562.8603 - mae: 657.1833 - val_loss: 626721.7500 - val_mae: 606.0674
# Epoch 56/80
# 2/2 [==============================] - 0s 44ms/step - loss: 725128.0009 - mae: 648.5873 - val_loss: 1332240.8750 - val_mae: 929.0836
# Epoch 57/80
# 2/2 [==============================] - 0s 49ms/step - loss: 754018.8366 - mae: 652.4756 - val_loss: 1102063.0000 - val_mae: 816.6396
# Epoch 58/80
# 2/2 [==============================] - 0s 46ms/step - loss: 744570.8267 - mae: 655.6426 - val_loss: 1346566.3750 - val_mae: 909.3948
# Epoch 59/80
# 2/2 [==============================] - 0s 55ms/step - loss: 659315.2662 - mae: 607.5370 - val_loss: 1148533.7500 - val_mae: 844.1432
# Epoch 60/80
# 2/2 [==============================] - 0s 46ms/step - loss: 844059.2655 - mae: 630.2263 - val_loss: 839736.7500 - val_mae: 775.9953
# Epoch 61/80
# 2/2 [==============================] - 0s 49ms/step - loss: 1088984.9382 - mae: 809.5909 - val_loss: 1033592.0000 - val_mae: 839.5553
# Epoch 62/80
# 2/2 [==============================] - 0s 49ms/step - loss: 863015.8600 - mae: 674.1643 - val_loss: 984026.7500 - val_mae: 836.6501
# Epoch 63/80
# 2/2 [==============================] - 0s 46ms/step - loss: 875883.4865 - mae: 674.9033 - val_loss: 921319.8125 - val_mae: 804.1241
# Epoch 64/80
# 2/2 [==============================] - 0s 45ms/step - loss: 752778.8014 - mae: 625.5533 - val_loss: 874471.5000 - val_mae: 770.9255
# Epoch 65/80
# 2/2 [==============================] - 0s 78ms/step - loss: 715772.9320 - mae: 622.3528 - val_loss: 824873.8750 - val_mae: 742.3813
# Epoch 66/80
# 2/2 [==============================] - 0s 77ms/step - loss: 760415.6238 - mae: 644.6794 - val_loss: 752971.5000 - val_mae: 702.6291
# Epoch 67/80
# 2/2 [==============================] - 0s 67ms/step - loss: 714430.9345 - mae: 598.1160 - val_loss: 714167.8125 - val_mae: 671.0526
# Epoch 68/80
# 2/2 [==============================] - 0s 52ms/step - loss: 670482.3975 - mae: 596.5975 - val_loss: 686253.6250 - val_mae: 665.9218
# Epoch 69/80
# 2/2 [==============================] - 0s 49ms/step - loss: 647118.7490 - mae: 577.5616 - val_loss: 672567.0000 - val_mae: 655.6055
# Epoch 70/80
# 2/2 [==============================] - 0s 51ms/step - loss: 663099.3128 - mae: 584.8887 - val_loss: 659078.7500 - val_mae: 661.0278
# Epoch 71/80
# 2/2 [==============================] - 0s 58ms/step - loss: 617597.5437 - mae: 568.1989 - val_loss: 673759.3125 - val_mae: 680.2140
# Epoch 72/80
# 2/2 [==============================] - 0s 85ms/step - loss: 631418.5002 - mae: 572.4603 - val_loss: 676548.3125 - val_mae: 660.2949
# Epoch 73/80
# 2/2 [==============================] - 0s 77ms/step - loss: 713747.1771 - mae: 620.4706 - val_loss: 720752.8125 - val_mae: 687.0266
# Epoch 74/80
# 2/2 [==============================] - 0s 73ms/step - loss: 647529.7498 - mae: 591.3266 - val_loss: 795642.7500 - val_mae: 718.9608
# Epoch 75/80
# 2/2 [==============================] - 0s 66ms/step - loss: 624936.6136 - mae: 582.4200 - val_loss: 783893.0000 - val_mae: 709.1354
# Epoch 76/80
# 2/2 [==============================] - 0s 59ms/step - loss: 598597.4714 - mae: 563.1632 - val_loss: 711363.1875 - val_mae: 673.1763
# Epoch 77/80
# 2/2 [==============================] - 0s 54ms/step - loss: 586059.8329 - mae: 555.1912 - val_loss: 798543.5625 - val_mae: 686.7364
# Epoch 78/80
# 2/2 [==============================] - 0s 46ms/step - loss: 600895.2645 - mae: 565.8960 - val_loss: 698334.6875 - val_mae: 648.9543
# Epoch 79/80
# 2/2 [==============================] - 0s 62ms/step - loss: 558518.3339 - mae: 539.3375 - val_loss: 661119.2500 - val_mae: 632.7843
# Epoch 80/80
# 2/2 [==============================] - 0s 78ms/step - loss: 581213.1518 - mae: 552.5715 - val_loss: 618784.6875 - val_mae: 608.7139

# %%
train_loss = hist.history['loss']
test_loss = hist.history['val_loss']

# %%
fig, ax = plt.subplots(figsize=(16,9))
plt.plot(hist.history['loss'], label='Train loss')
plt.plot(hist.history['val_loss'], label='Test loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend();

# %% [markdown]
# ### Prediction Forecasting

# %%
trainPredict = model.predict(train_seq)
testPredict = model.predict(test_seq)

# %%
trainPredict0 = trainPredict[:,0]
trainPredict1 = trainPredict[:,1]
trainPredict2 = trainPredict[:,2]
trainPredict3 = trainPredict[:,3]

# %%
testPredict0 = testPredict[:,0]
testPredict1 = testPredict[:,1]
testPredict2 = testPredict[:,2]
testPredict3 = testPredict[:,3]

# %%
Trial = (trainPredict0 + trainPredict1 + trainPredict2 + trainPredict3)/4

# %%
TrialX = np.append((trainPredict[0]), Trial)

# %%
Test = (testPredict0 + testPredict1 + testPredict2 + testPredict3)/4

# %%
TestX = np.append(testPredict[0], Test)

# %%
fig, ax = plt.subplots(figsize=(16,9))
plt.plot(TrialX, label = 'Train')
plt.plot([None for i in TrialX] + [x for x in TestX], label = 'Test')
plt.plot(target, label = 'Actual Price', color = 'black')
plt.xlabel('Timestamp')
plt.ylabel('Price')
plt.title('Train/Test Vs Actual')
plt.legend();

# %% [markdown]
# ### Model Evaluation

# %%
scores = model.evaluate(train_seq, verbose=2)
# Out:
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# 2/2 - 0s - loss: 568020.6250 - mae: 543.7972

# %%
print('Model Features: BTC Prices & General Public Sentiment Scores')
model.summary()
print('Model RMSE Score: %2f' % (scores[0]**0.5))
print('Model MAE Score: %2f' % (scores[1]))
print('-' * 65)
# Out:
# Model Features: BTC Prices & General Public Sentiment Scores
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 3, 64)             18432
# _________________________________________________________________
# dense (Dense)                (None, 3, 1)              65
# =================================================================
# Total params: 18,497
# Trainable params: 18,497
# Non-trainable params: 0
# _________________________________________________________________
# Model RMSE Score: 753.671430
# Model MAE Score: 543.797180
# -----------------------------------------------------------------
