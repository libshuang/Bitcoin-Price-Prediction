# %%
import pandas as pd

from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, GRU, LSTM
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator

import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Import Data

# %%
df = pd.read_csv('./Reddit_data/Combined_Yearly_Data/stage6_sent2019.csv')#, usecols=[2])
df
# Out:
#          Date    score_x  vader_neu_score_x  vader_pos_score_x  \
# 0    1/1/2019   1.000000           0.779817           0.150914
# 1    1/2/2019   1.000000           0.788895           0.132738
# 2    1/3/2019   1.000000           0.762514           0.157115
# 3    1/4/2019   1.000000           0.823124           0.131052
# 4    1/5/2019   1.000000           0.771269           0.155856
# ..        ...        ...                ...                ...
# 365  1/2/2020   7.971751           0.772073           0.144390
# 366  1/3/2020  23.602151           0.777473           0.152199
# 367  1/4/2020  20.180328           0.798306           0.137716
# 368  1/5/2020   2.093333           0.757693           0.192093
# 369  1/6/2020   1.000000           0.751836           0.184673
#
#      vader_neg_score_x  vader_compound_x  blob_polarity_x  \
# 0             0.063560          0.244091         0.141259
# 1             0.078350          0.148628         0.072468
# 2             0.070226          0.204104         0.115714
# 3             0.045803          0.198445         0.119178
# 4             0.072892          0.186405         0.105184
# ..                 ...               ...              ...
# 365           0.077870          0.173630         0.079489
# 366           0.070312          0.132112         0.088039
# 367           0.063989          0.154446         0.106286
# 368           0.050173          0.244745         0.123193
# 369           0.063436          0.292373         0.126815
#
#      blob_subjectivity_x  score_y  vader_neu_score_y  ...  vader_neg_score_y  \
# 0               0.314487      175            136.468  ...             11.123
# 1               0.287114      286            225.624  ...             22.408
# 2               0.331457      296            225.704  ...             20.787
# 3               0.283849      233            191.788  ...             10.672
# 4               0.317282      167            128.802  ...             12.173
# ..                   ...      ...                ...  ...                ...
# 365             0.289152     1411            136.657  ...             13.783
# 366             0.271746     4390            144.610  ...             13.078
# 367             0.303051     3693            146.090  ...             11.710
# 368             0.273214      314            113.654  ...              7.526
# 369             0.335220       55             41.351  ...              3.489
#
#      vader_compound_y  blob_polarity_y  blob_subjectivity_y  count_y  \
# 0             42.7160        24.720324            55.035224      175
# 1             42.5077        20.725735            82.114492      286
# 2             60.4147        34.251326            98.111408      296
# 3             46.2377        27.768522            66.136730      233
# 4             31.1297        17.565797            52.986176      167
# ..                ...              ...                  ...      ...
# 365           30.7325        14.069506            51.179923      177
# 366           24.5729        16.375188            50.544828      186
# 367           28.2637        19.450301            55.458384      183
# 368           36.7118        18.478918            40.982033      150
# 369           16.0805         6.974847            18.437123       55
#
#      Closing Price (USD)  24h Open (USD)  24h High (USD)  24h Low (USD)  \
# 0            3715.564441     3693.330067     3741.881855    3644.876282
# 1            3882.304754     3715.564384     3900.709127    3711.274108
# 2            3795.592741     3882.303622     3916.197684    3760.944042
# 3            3812.381108     3781.020706     3844.986111    3725.739663
# 4            3809.914343     3812.381119     3866.417432    3775.828878
# ..                   ...             ...             ...            ...
# 365          6955.487580     7174.712357     7190.188749    6914.857474
# 366          7291.219505     6955.487580     7390.041835    6852.093401
# 367          7337.636670     7291.217504     7390.762935    7263.178696
# 368          7347.433264     7337.421391     7487.333871    7316.763370
# 369          7713.860754     7351.578890     7749.648613    7339.702523
#
#      Difference
# 0     25.999821
# 1    166.740313
# 2    -86.712013
# 3     16.788367
# 4     -2.466765
# ..          ...
# 365 -219.256432
# 366  335.731925
# 367   46.417165
# 368    9.796594
# 369  366.427490
#
# [370 rows x 21 columns]

# %%
feature_df = df[['Closing Price (USD)']]

# %%
target = df[['Closing Price (USD)']]

# %% [markdown]
# ### LSTM Forecasting

# %%
look_back = 4

# %%
# Create X and y
X = feature_df
y = target.values
# Train/Test Split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2,shuffle = False, random_state = 13)
# Scale
ss = StandardScaler()
X_train_sc = ss.fit_transform(X_train)
X_test_sc = ss.transform(X_test)
# Create training sequences
train_seq = TimeseriesGenerator(X_train_sc, y_train, length = look_back, batch_size = 128)
# Create test sequences
test_seq = TimeseriesGenerator(X_test_sc, y_test, length = look_back, batch_size = 128)

# %%
model = Sequential()

model.add(LSTM(64, input_shape=(3,1), return_sequences = True))
model.add(Dense(1))

model.compile(loss='mean_squared_error', optimizer='sgd', metrics = ['mape'])

# %%
hist = model.fit(train_seq, epochs=80, validation_data = test_seq)
# Out:
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 3 steps, validate for 1 steps
# Epoch 1/80
# 3/3 [==============================] - 5s 2s/step - loss: 54991504.8630 - mape: 92.8864 - val_loss: 5847229.0000 - val_mape: 27.0550
# Epoch 2/80
# 3/3 [==============================] - 0s 44ms/step - loss: 8683859.1918 - mape: 32.6197 - val_loss: 2686476.7500 - val_mape: 18.5831
# Epoch 3/80
# 3/3 [==============================] - 0s 33ms/step - loss: 5621276.0539 - mape: 37.7775 - val_loss: 1873770.2500 - val_mape: 15.5236
# Epoch 4/80
# 3/3 [==============================] - 0s 35ms/step - loss: 2659196.7209 - mape: 21.5535 - val_loss: 857540.3125 - val_mape: 10.3706
# Epoch 5/80
# 3/3 [==============================] - 0s 36ms/step - loss: 1704776.0527 - mape: 19.0317 - val_loss: 765009.0000 - val_mape: 7.4690
# Epoch 6/80
# 3/3 [==============================] - 0s 40ms/step - loss: 2576657.6498 - mape: 26.4601 - val_loss: 857515.1875 - val_mape: 10.9212
# Epoch 7/80
# 3/3 [==============================] - 0s 44ms/step - loss: 2171273.8804 - mape: 22.6236 - val_loss: 308225.8125 - val_mape: 6.4841
# Epoch 8/80
# 3/3 [==============================] - 0s 40ms/step - loss: 1932674.6729 - mape: 19.7767 - val_loss: 909971.4375 - val_mape: 11.2578
# Epoch 9/80
# 3/3 [==============================] - 0s 39ms/step - loss: 1130132.5522 - mape: 15.5293 - val_loss: 587658.3750 - val_mape: 9.0752
# Epoch 10/80
# 3/3 [==============================] - 0s 40ms/step - loss: 1134310.6248 - mape: 15.0576 - val_loss: 621560.3125 - val_mape: 9.5494
# Epoch 11/80
# 3/3 [==============================] - 0s 38ms/step - loss: 1626409.9110 - mape: 18.0042 - val_loss: 631999.3125 - val_mape: 9.4853
# Epoch 12/80
# 3/3 [==============================] - 0s 40ms/step - loss: 1561441.1074 - mape: 16.3083 - val_loss: 891017.5000 - val_mape: 11.4817
# Epoch 13/80
# 3/3 [==============================] - 0s 36ms/step - loss: 1703448.3861 - mape: 17.4906 - val_loss: 943295.6875 - val_mape: 11.7197
# Epoch 14/80
# 3/3 [==============================] - 0s 37ms/step - loss: 1567892.3878 - mape: 18.9778 - val_loss: 797222.5625 - val_mape: 10.8805
# 3/3 [==============================] - 0s 37ms/step - loss: 790665.4105 - mape: 10.8867 - val_loss: 894380.9375 - val_mape: 11.0777
# Epoch 75/80
# 3/3 [==============================] - 0s 40ms/step - loss: 820991.7635 - mape: 9.1986 - val_loss: 1754661.8750 - val_mape: 15.8629
# Epoch 76/80
# 3/3 [==============================] - 0s 38ms/step - loss: 925367.5789 - mape: 9.7796 - val_loss: 1765354.3750 - val_mape: 15.9521
# Epoch 77/80
# 3/3 [==============================] - 0s 36ms/step - loss: 1017257.0918 - mape: 13.3319 - val_loss: 800016.2500 - val_mape: 10.3346
# Epoch 78/80
# 3/3 [==============================] - 0s 36ms/step - loss: 1010813.9542 - mape: 10.4643 - val_loss: 722500.8750 - val_mape: 9.8281
# Epoch 79/80
# 3/3 [==============================] - 0s 43ms/step - loss: 1066431.7640 - mape: 10.6121 - val_loss: 1487582.7500 - val_mape: 14.4287
# Epoch 80/80
# 3/3 [==============================] - 0s 42ms/step - loss: 1084445.6398 - mape: 10.8343 - val_loss: 1321438.1250 - val_mape: 13.5999

# %%
model.evaluate(train_seq, verbose=1)
# Out:
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# 3/3 [==============================] - 0s 8ms/step - loss: 868878.7708 - mape: 12.0499
# [868878.7708333334, 12.04991]

# %%
train_loss = hist.history['loss']
test_loss = hist.history['val_loss']

# %%
fig, ax = plt.subplots(figsize=(16,9))
plt.plot(hist.history['loss'], label='Train loss')
plt.plot(hist.history['val_loss'], label='Test loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend();

# %% [markdown]
# ### Prediction Forecasting

# %%
trainPredict = model.predict(train_seq)
testPredict = model.predict(test_seq)

trainPredict0 = trainPredict[:,0]
trainPredict1 = trainPredict[:,1]
trainPredict2 = trainPredict[:,2]
trainPredict3 = trainPredict[:,3]
Trial = (trainPredict0 + trainPredict1 + trainPredict2 + trainPredict3)/4

testPredict0 = testPredict[:,0]
testPredict1 = testPredict[:,1]
testPredict2 = testPredict[:,2]
testPredict3 = testPredict[:,3]
Test = (testPredict0 + testPredict1 + testPredict2 + testPredict3)/4

#add the last 4 lookbacks from the train and test Predict
TrialX = np.append((trainPredict[0]), Trial)
TestX = np.append(testPredict[0], Test)

# %%
fig, ax = plt.subplots(figsize=(16,9))
plt.plot(TrialX, label = 'Train')
plt.plot([None for i in TrialX] + [x for x in TestX], label = 'Test')
plt.plot(target, label = 'Actual Price', color = 'black')
plt.xlabel('Timestamp (2019)')
plt.ylabel('Price')
plt.title('Naive Baseline')
plt.legend();

# %%
scores = model.evaluate(train_seq, verbose=2)
# Out:
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# 3/3 - 0s - loss: 868878.7708 - mape: 12.0499

# %%
print('Model Features: BTC Prices & General Public Sentiment Scores')
model.summary()
print('Model RMSE Score: %2f' % (scores[0]**0.5))
print('Model MAE Score: %2f' % (scores[1]))
print('-' * 65)
# Out:
# Model Features: BTC Prices & General Public Sentiment Scores
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 3, 64)             16896
# _________________________________________________________________
# dense (Dense)                (None, 3, 1)              65
# =================================================================
# Total params: 16,961
# Trainable params: 16,961
# Non-trainable params: 0
# _________________________________________________________________
# Model RMSE Score: 932.136670
# Model MAE Score: 12.049910
# -----------------------------------------------------------------
